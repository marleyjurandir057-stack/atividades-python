# %% [markdown]
# <a href="https://colab.research.google.com/github/marleyjurandir057-stack/atividades-python/blob/main/atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Atividade 01- Introdução ao Python

# %%
print("Olá Mundo")
# Out:
# Olá Mundo

# %%
print("Curso Técnico em Informática")
# Out:
# Curso Técnico em Informática

# %%
disciplina=input("Digite o nome da disciplina:")
conteudo=input("Digite o conteúdo estudado:")
atividade=input("Digite o número da atividade:")
print("\n---Informações da atividade---")
print("Disciplina: ",disciplina)
print("Conteúdo: ",conteudo)
print("Atividade: ", atividade)
# Out:
# Digite o nome da disciplina:geografia
# Digite o conteúdo estudado:demografia
# Digite o número da atividade:02
#
# ---Informações da atividade---
# Disciplina:  geografia
# Conteúdo:  demografia
# Atividade:  02
